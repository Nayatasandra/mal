# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyclustering.cluster.cure import cure
from pyclustering.utils import read_sample
from pyclustering.cluster import cluster_visualizer_multidim
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import joblib
import seaborn as sns

# %%
# Baca data CSV
data = pd.read_csv('dataset.csv')

# %%
# Tampilkan beberapa baris awal data
print("Head dari data awal:")
print(data.head())
# Out:
# Head dari data awal:
#                 Nama  Umur Jenis_Kelamin  LiLA  Berat_Badan  Tinggi_Badan  \
# 0            Junaidi    90     Laki-laki    36           70           166
# 1             Tumini    82     Perempuan    30           56           145
# 2  Yusraidi Sitompul    74     Laki-laki    34           52           146
# 3        Yuni Astuti    60     Perempuan    21           48           146
# 4           Yulwanda    69     Perempuan    25           51           170
#
#    Penurunan_Berat_Badan       Frekuensi_Makan  \
# 0                      0  Tiga kali atau lebih
# 1                      0  Tiga kali atau lebih
# 2                      0  Tiga kali atau lebih
# 3                      0  Tiga kali atau lebih
# 4                      0  Tiga kali atau lebih
#
#                                      Variasi_Makanan  \
# 0  Makanan bervariasi (misalnya daging, sayuran, ...
# 1  Makanan bervariasi (misalnya daging, sayuran, ...
# 2  Makanan bervariasi (misalnya daging, sayuran, ...
# 3  Makanan bervariasi (misalnya daging, sayuran, ...
# 4  Makanan bervariasi (misalnya daging, sayuran, ...
#
#                Asupan_Protein                            Mobilitas  \
# 0  Dua kali sehari atau lebih  Bergerak dengan bebas tanpa bantuan
# 1  Dua kali sehari atau lebih  Bergerak dengan bebas tanpa bantuan
# 2  Dua kali sehari atau lebih  Bergerak dengan bebas tanpa bantuan
# 3  Dua kali sehari atau lebih  Bergerak dengan bebas tanpa bantuan
# 4  Dua kali sehari atau lebih  Bergerak dengan bebas tanpa bantuan
#
#   Aktivitas_Sehari_hari    Kesehatan_Mulut Penyakit_Kronis  Stres  \
# 0   Tidak ada kesulitan  Tidak ada masalah           Tidak  Tidak
# 1   Tidak ada kesulitan  Tidak ada masalah           Tidak  Tidak
# 2   Tidak ada kesulitan  Tidak ada masalah           Tidak  Tidak
# 3   Tidak ada kesulitan  Tidak ada masalah           Tidak  Tidak
# 4   Tidak ada kesulitan  Tidak ada masalah           Tidak  Tidak
#
#                  Masalah_Kognitif
# 0  Ada sedikit masalah daya ingat
# 1  Ada sedikit masalah daya ingat
# 2    Tidak ada masalah daya ingat
# 3    Tidak ada masalah daya ingat
# 4    Tidak ada masalah daya ingat

# %%
# Lihat deskripsi statistik dari data
print("\nDeskripsi Statistik:")
print(data.describe())
# Out:
# Deskripsi Statistik:
#              Umur        LiLA  Berat_Badan  Tinggi_Badan  \
# count  517.000000  517.000000   517.000000    517.000000
# mean    67.920696   29.417795    58.003868    156.352031
# std      5.650641    4.971967    10.793695      8.711786
# min     56.000000   19.000000    34.000000    135.000000
# 25%     64.000000   26.000000    50.000000    149.000000
# 50%     67.000000   29.000000    58.000000    156.000000
# 75%     71.000000   33.000000    65.000000    163.000000
# max     93.000000   40.000000   165.000000    179.000000
#
#        Penurunan_Berat_Badan
# count             517.000000
# mean                0.549323
# std                 1.063846
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 1.000000
# max                 5.000000

# %%
# Visualisasikan distribusi berat badan
plt.figure(figsize=(10,6))
sns.histplot(data['Berat_Badan'], kde=True, color='blue')
plt.title('Distribusi Berat Badan')
plt.xlabel('Berat Badan')
plt.ylabel('Frekuensi')
plt.show()

# %%
# Mengonversi kolom teks menjadi numerik (untuk kolom frekuensi makan, variasi makanan, dsb.)
data = data.applymap(lambda x: x.strip() if isinstance(x, str) else x)
data['Jenis_Kelamin'] = data['Jenis_Kelamin'].map({'Perempuan': 1, 'Laki-laki': 0})
data['Penyakit_Kronis'] = data['Penyakit_Kronis'].map({
    'Ya': 1, 'Tidak': 0,
    'Ya (Hipertensi)':2,
    'Ya (Diabetes)':3,
    'Ya (Diabetes, Hipertensi)':4
})
data['Stres'] = data['Stres'].map({'Ya': 1, 'Tidak': 0})
data['Frekuensi_Makan'] = data['Frekuensi_Makan'].map({
    'Tiga kali atau lebih':3,
    'Dua kali': 2,
    'Satu kali atau kurang': 1
})

data['Variasi_Makanan'] = data['Variasi_Makanan'].map({
    'Makanan bervariasi (misalnya daging, sayuran, buah)': 3,
    'Makanan terbatas pada beberapa jenis saja': 2,
    'Makanan sangat terbatas atau monoton': 1
})

data['Asupan_Protein'] = data['Asupan_Protein'].map({
    'Dua kali sehari atau lebih': 3,
    'Sekali sehari': 2,
    'Kurang dari sekali sehari atau tidak pernah':1
})

data['Mobilitas']=data['Mobilitas'].map({
    'Bergerak dengan bebas tanpa bantuan':3,
    'Bergerak dengan bantuan':2,
    'Tidak dapat bergerak tanpa bantuan orang lain':1
})

data['Aktivitas_Sehari_hari']=data['Aktivitas_Sehari_hari'].map({
    'Tidak ada kesulitan':3,
    'Kesulitan ringan':2,
    'Kesulitan berat':1
})

data['Kesehatan_Mulut']=data['Kesehatan_Mulut'].map({
    'Tidak ada masalah':4,
    'Ada kesulitan ringan':3,
    'Kesulitan berat':2,
    'Kesulitan berat dalam mengunyah atau makan':1
})

data['Masalah_Kognitif']=data['Masalah_Kognitif'].map({
    'Tidak ada masalah daya ingat':3,
    'Ada sedikit masalah daya ingat':2,
    'Masalah daya ingat yang signifikan':1
})

# %%
# Tampilkan data yang sudah dikonversi
print("\nData setelah konversi kategorikal:")
print(data.head())
# Out:
# Data setelah konversi kategorikal:
#                 Nama  Umur  Jenis_Kelamin  LiLA  Berat_Badan  Tinggi_Badan  \
# 0            Junaidi    90              0    36           70           166
# 1             Tumini    82              1    30           56           145
# 2  Yusraidi Sitompul    74              0    34           52           146
# 3        Yuni Astuti    60              1    21           48           146
# 4           Yulwanda    69              1    25           51           170
#
#    Penurunan_Berat_Badan  Frekuensi_Makan  Variasi_Makanan  Asupan_Protein  \
# 0                      0                3                3               3
# 1                      0                3                3               3
# 2                      0                3                3               3
# 3                      0                3                3               3
# 4                      0                3                3               3
#
#    Mobilitas  Aktivitas_Sehari_hari  Kesehatan_Mulut  Penyakit_Kronis  Stres  \
# 0          3                      3                4              0.0      0
# 1          3                      3                4              0.0      0
# 2          3                      3                4              0.0      0
# 3          3                      3                4              0.0      0
# 4          3                      3                4              0.0      0
#
#    Masalah_Kognitif
# 0                 2
# 1                 2
# 2                 3
# 3                 3
# 4                 3

# %%
# Isi missing values (jika ada)
data.fillna(data.mean(), inplace=True)
# Out:
# C:\Users\ASUS TUF F15\AppData\Local\Temp\ipykernel_5588\1844191685.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.mean(), inplace=True)

# %%
from sklearn.preprocessing import RobustScaler
# Normalisasi data (kecuali kolom 'Nama')
# scaler = RobustScaler()
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data.drop(columns=['Nama']))
# simpan scaled_data
joblib.dump(scaled_data, 'scaled_data.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
# Tampilkan data yang sudah dinormalisasi
print("\nData setelah normalisasi (5 baris pertama):")
print(pd.DataFrame(scaled_data, columns=data.columns[1:]).head())
# Out:
# Data setelah normalisasi (5 baris pertama):
#        Umur  Jenis_Kelamin      LiLA  Berat_Badan  Tinggi_Badan  \
# 0  3.911182      -1.061872  1.325146     1.112478      1.108534
# 1  2.494043       0.941733  0.117211    -0.185832     -1.304328
# 2  1.076903      -1.061872  0.922501    -0.556777     -1.189430
# 3 -1.403092       0.941733 -1.694691    -0.927723     -1.189430
# 4  0.191191       0.941733 -0.889401    -0.649514      1.568127
#
#    Penurunan_Berat_Badan  Frekuensi_Makan  Variasi_Makanan  Asupan_Protein  \
# 0              -0.516856         0.755012         0.851759        0.773382
# 1              -0.516856         0.755012         0.851759        0.773382
# 2              -0.516856         0.755012         0.851759        0.773382
# 3              -0.516856         0.755012         0.851759        0.773382
# 4              -0.516856         0.755012         0.851759        0.773382
#
#    Mobilitas  Aktivitas_Sehari_hari  Kesehatan_Mulut  Penyakit_Kronis  \
# 0   0.958431                1.08384         1.122443        -1.160984
# 1   0.958431                1.08384         1.122443        -1.160984
# 2   0.958431                1.08384         1.122443        -1.160984
# 3   0.958431                1.08384         1.122443        -1.160984
# 4   0.958431                1.08384         1.122443        -1.160984
#
#       Stres  Masalah_Kognitif
# 0 -1.074321         -0.044646
# 1 -1.074321         -0.044646
# 2 -1.074321          1.313119
# 3 -1.074321          1.313119
# 4 -1.074321          1.313119

# %%
import scipy.spatial.distance as distance
from sklearn.decomposition import PCA

# Distance function
def dist(vecA, vecB):
    return np.sqrt(np.power(vecA - vecB, 2).sum())

# CURE Cluster class
class CureCluster:
    def __init__(self, id__, center__):
        self.points = np.array(center__)
        self.repPoints = np.array(center__)
        self.center = np.array(center__)
        self.index = [id__]

    def __repr__(self):
        return "Cluster " + " Size: " + str(len(self.points))

    def computeCentroid(self, clust):
        totalPoints_1 = len(self.index)
        totalPoints_2 = len(clust.index)
        self.center = (self.center * totalPoints_1 + clust.center * totalPoints_2) / (totalPoints_1 + totalPoints_2)

    def generateRepPoints(self, numRepPoints, alpha):
        tempSet = None
        for i in range(1, numRepPoints + 1):
            maxDist = 0
            maxPoint = None
            for p in range(len(self.index)):
                if i == 1:
                    minDist = dist(self.points[p, :], self.center)
                else:
                    X = np.vstack([tempSet, self.points[p, :]])
                    tmpDist = distance.pdist(X)
                    minDist = tmpDist.min()
                if minDist >= maxDist:
                    maxDist = minDist
                    maxPoint = self.points[p, :]
            if tempSet is None:
                tempSet = maxPoint
            else:
                tempSet = np.vstack((tempSet, maxPoint))
        for j in range(len(tempSet)):
            if self.repPoints is None:
                self.repPoints = tempSet[j, :] + alpha * (self.center - tempSet[j, :])
            else:
                self.repPoints = np.vstack((self.repPoints, tempSet[j, :] + alpha * (self.center - tempSet[j, :])))

    def distRep(self, clust):
        distRep = float('inf')
        for repA in self.repPoints:
            if type(clust.repPoints[0]) != list:
                repB = clust.repPoints
                distTemp = dist(repA, repB)
                if distTemp < distRep:
                    distRep = distTemp
            else:
                for repB in clust.repPoints:
                    distTemp = dist(repA, repB)
                    if distTemp < distRep:
                        distRep = distTemp
        return distRep

    def mergeWithCluster(self, clust, numRepPoints, alpha):
        self.computeCentroid(clust)
        self.points = np.vstack((self.points, clust.points))
        self.index = np.append(self.index, clust.index)
        self.repPoints = None
        self.generateRepPoints(numRepPoints, alpha)

# Function to run CURE
def runCURE(data, numRepPoints, alpha, numDesCluster):
    Clusters = []
    numCluster = len(data)
    numPts = len(data)
    distCluster = np.ones([len(data), len(data)]) * float('inf')
    
    for idPoint in range(len(data)):
        newClust = CureCluster(idPoint, data[idPoint, :])
        Clusters.append(newClust)

    for row in range(numPts):
        for col in range(row):
            distCluster[row][col] = dist(Clusters[row].center, Clusters[col].center)
    
    while numCluster > numDesCluster:
        if np.mod(numCluster, 50) == 0:
            print('Cluster count:', numCluster)

        minIndex = np.where(distCluster == np.min(distCluster))
        minIndex1, minIndex2 = minIndex[0][0], minIndex[1][0]

        Clusters[minIndex1].mergeWithCluster(Clusters[minIndex2], numRepPoints, alpha)

        for i in range(0, minIndex1):
            distCluster[minIndex1, i] = Clusters[minIndex1].distRep(Clusters[i])
        for i in range(minIndex1 + 1, numCluster):
            distCluster[i, minIndex1] = Clusters[minIndex1].distRep(Clusters[i])

        distCluster = np.delete(distCluster, minIndex2, axis=0)
        distCluster = np.delete(distCluster, minIndex2, axis=1)
        del Clusters[minIndex2]
        numCluster -= 1

    print('Cluster count:', numCluster)
    
    Label = [0] * numPts
    for i in range(len(Clusters)):
        for j in range(len(Clusters[i].index)):
            Label[Clusters[i].index[j]] = i + 1

    return Clusters, Label  # Return both Clusters and Label


data_scaled = pd.DataFrame(scaled_data)

# Parameter CURE
numRepPoints = 5
alpha = 0.5
numDesCluster = 4

# Menjalankan CURE
data_np = data_scaled.values
clusters, labels = runCURE(data_np, numRepPoints, alpha, numDesCluster)  # Get Clusters

# Visualisasi dengan PCA
pca = PCA(n_components=0.95)
data_pca = pca.fit_transform(data_np)
# Out:
# Cluster count: 500
# Cluster count: 450
# Cluster count: 400
# Cluster count: 350
# Cluster count: 300
# Cluster count: 250
# Cluster count: 200
# Cluster count: 150
# Cluster count: 100
# Cluster count: 50
# Cluster count: 4

# %%
plt.figure(figsize=(10, 8))
plt.scatter(data_pca[:, 0], data_pca[:, 1], c=labels, cmap='viridis', alpha=0.6)
plt.title('Clustering Hasil CURE (Dengan PCA)')
plt.xlabel('Komponen Utama 1')
plt.ylabel('Komponen Utama 2')
plt.colorbar(label='Label Cluster')
plt.grid(True)
plt.show()

# %%
# Count the occurrences of each label
unique_labels, counts = np.unique(labels, return_counts=True)

# Create a DataFrame to display the cluster sizes
cluster_sizes = pd.DataFrame({'Cluster': unique_labels, 'Size': counts})

# Display the cluster sizes
print(cluster_sizes)

# Optional: Visualize the cluster sizes
plt.figure(figsize=(10, 5))
plt.bar(cluster_sizes['Cluster'].astype(str), cluster_sizes['Size'], color='skyblue')
plt.title('Distribution of Points in Each Cluster')
plt.xlabel('Cluster')
plt.ylabel('Number of Points')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
#    Cluster  Size
# 0        1    22
# 1        2   183
# 2        3     1
# 3        4   311

# %%
import joblib

# Save the representative points of the clusters
def save_model(clusters, filename='cure_model.pkl'):
    rep_points = []
    for cluster in clusters:
        rep_points.append(cluster.repPoints)
    joblib.dump(rep_points, filename)

# Call this function after running CURE
save_model(clusters)

# %%
# Load the representative points of the clusters
def load_model(filename='cure_model.pkl'):
    return joblib.load(filename)

# %%
# Load the fitted scaler
def load_scaler(filename='scaler.pkl'):
    return joblib.load(filename)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyclustering.cluster.cure import cure
from pyclustering.utils import read_sample
from pyclustering.cluster import cluster_visualizer_multidim
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import joblib
import seaborn as sns


# Preprocess the new data
def preprocess_data(data):
    # Clean and encode the data as per your previous definitions
    data = data.applymap(lambda x: x.strip() if isinstance(x, str) else x)
    data['Jenis_Kelamin'] = data['Jenis_Kelamin'].map({'Perempuan': 1, 'Laki-laki': 0})
    data['Penyakit_Kronis'] = data['Penyakit_Kronis'].map({
        'Ya': 1, 'Tidak': 0,
        'Ya (Hipertensi)': 2,
        'Ya (Diabetes)': 3,
        'Ya (Diabetes, Hipertensi)': 4
    })
    data['Stres'] = data['Stres'].map({'Ya': 1, 'Tidak': 0})
    data['Frekuensi_Makan'] = data['Frekuensi_Makan'].map({
        'Tiga kali atau lebih': 3,
        'Dua kali': 2,
        'Satu kali atau kurang': 1
    })
    data['Variasi_Makanan'] = data['Variasi_Makanan'].map({
        'Makanan bervariasi (misalnya daging, sayuran, buah)': 3,
        'Makanan terbatas pada beberapa jenis saja': 2,
        'Makanan sangat terbatas atau monoton': 1
    })
    data['Asupan_Protein'] = data['Asupan_Protein'].map({
        'Dua kali sehari atau lebih': 3,
        'Sekali sehari': 2,
        'Kurang dari sekali sehari atau tidak pernah': 1
    })
    data['Mobilitas'] = data['Mobilitas'].map({
        'Bergerak dengan bebas tanpa bantuan': 3,
        'Bergerak dengan bantuan': 2,
        'Tidak dapat bergerak tanpa bantuan orang lain': 1
    })
    data['Aktivitas_Sehari_hari'] = data['Aktivitas_Sehari_hari'].map({
        'Tidak ada kesulitan': 3,
        'Kesulitan ringan': 2,
        'Kesulitan berat': 1
    })
    data['Kesehatan_Mulut'] = data['Kesehatan_Mulut'].map({
        'Tidak ada masalah': 4,
        'Ada kesulitan ringan': 3,
        'Kesulitan berat': 2,
        'Kesulitan berat dalam mengunyah atau makan': 1
    })
    data['Masalah_Kognitif'] = data['Masalah_Kognitif'].map({
        'Tidak ada masalah daya ingat': 3,
        'Ada sedikit masalah daya ingat': 2,
        'Masalah daya ingat yang signifikan': 1
    })

    # Seleksi hanya kolom numerik
    return data.drop(columns=['Nama'])

# Muat data baru
data_baru = pd.DataFrame({
    'Nama': ['Hasan'],
    'Umur': [75],
    'Jenis_Kelamin': ['Laki-laki'],
    'LiLA': [30],
    'Berat_Badan': [50],
    'Tinggi_Badan': [160],
    'Penurunan_Berat_Badan': [0],
    'Frekuensi_Makan': ['Dua kali'],
    'Variasi_Makanan': ['Makanan bervariasi (misalnya daging, sayuran, buah)'],
    'Asupan_Protein': ['Dua kali sehari atau lebih'],
    'Mobilitas': ['Bergerak dengan bebas tanpa bantuan'],
    'Aktivitas_Sehari_hari': ['Tidak ada kesulitan'],
    'Kesehatan_Mulut': ['Tidak ada masalah'],
    'Penyakit_Kronis': ['Tidak'],
    'Stres': ['Tidak'],
    'Masalah_Kognitif': ['Ada sedikit masalah daya ingat']
})

# Load scaler and model
scaler = load_scaler()
rep_points = load_model()

# Preprocess the new data
data_baru_preprocessed = preprocess_data(data_baru)

# Scale the new data
data_baru_scaled = scaler.transform(data_baru_preprocessed)

# Classify the new data
# def classify_new_data(new_data_scaled, clusters):
#     # Calculate distances to the representative points of the clusters
#     distances = []
#     for cluster in clusters:
#         # Calculate the distance to each representative point in the cluster
#         dist = np.linalg.norm(new_data_scaled - cluster.repPoints, axis=1)
#         distances.append(np.min(dist))  # Take the minimum distance to a representative point
#     return np.argmin(distances) + 1  # Return the cluster label (1-based)

# # Perform classification
# label_baru = classify_new_data(data_baru_scaled, clusters)

def classify_new_data(new_data_scaled, rep_points):
    # Calculate distances to the representative points of the clusters
    distances = []
    for reps in rep_points:
        # Calculate the distance to each representative point in the cluster
        dist = np.linalg.norm(new_data_scaled - reps, axis=1)
        distances.append(np.min(dist))  # Take the minimum distance to a representative point
    return np.argmin(distances) + 1  # Return the cluster label (1-based)

# Perform classification
label_baru = classify_new_data(data_baru_scaled, rep_points)

# Output the label of the new data
print(f"The new data belongs to cluster: {label_baru}")
# Out:
# The new data belongs to cluster: 2

# %%
# Fungsi untuk memberikan intervensi berdasarkan klaster
def intervensi(cluster):
    if cluster == 4:
        return ("Klaster 1 - Malnutrisi Berat:\n"
                "Ciri-ciri:\n"
                "• Penurunan berat badan yang signifikan (lebih dari 3 kg dalam 3 bulan terakhir).\n"
                "• Asupan makanan yang sangat rendah, kurang dari sekali makan sehari atau sangat monoton.\n"
                "• Mobilitas sangat terbatas, bergantung penuh pada orang lain atau alat bantu.\n"
                "• Masalah kesehatan mulut yang berat, seperti tidak dapat mengunyah atau makan dengan baik.\n"
                "• Penyakit kronis serius yang memperburuk kondisi gizi.\n"
                "• Masalah kognitif yang signifikan dan stres berat.\n"
                "Intervensi:\n"
                "• Pendekatan medis segera, dengan evaluasi menyeluruh oleh dokter, ahli gizi, dan tim medis lainnya.\n"
                "• Pemberian makanan atau nutrisi enteral/parenteral, jika diperlukan, untuk memastikan pasien mendapatkan nutrisi yang tepat.\n"
                "• Terapi fisik dan intervensi mobilitas untuk meningkatkan kekuatan fisik secara bertahap.\n"
                "• Konseling psikologis untuk mengurangi stres, depresi, atau kecemasan yang dapat memperburuk kondisi malnutrisi.\n")
    elif cluster == 3:
        return ("Klaster 2 - Malnutrisi Sedang:\n"
                "Ciri-ciri:\n"
                "• Penurunan berat badan antara 1-3 kg dalam 3 bulan terakhir.\n"
                "• Asupan makanan terbatas pada dua kali makan sehari dengan variasi makanan yang kurang.\n"
                "• Mobilitas terbatas, tetapi masih bisa bergerak dengan alat bantu (tongkat, walker).\n"
                "• Ada kesulitan mengunyah makanan, tetapi masih dapat mengonsumsi makanan lunak.\n"
                "• Mengalami stres ringan dan memiliki penyakit kronis yang dapat memengaruhi status gizi.\n"
                "Intervensi:\n"
                "• Konsultasi ahli gizi untuk merancang rencana makan yang lebih kaya nutrisi dan bervariasi.\n"
                "• Program rehabilitasi fisik yang ringan untuk meningkatkan mobilitas dan kekuatan fisik.\n"
                "• Pemberian suplemen gizi, terutama untuk meningkatkan asupan protein dan mikronutrien.\n"
                "• Pengawasan berkala oleh tenaga medis untuk mencegah perkembangan ke malnutrisi berat.\n")
    elif cluster == 2:
        return ("Klaster 3 - Malnutrisi Ringan:\n"
                "Ciri-ciri:\n"
                "• Penurunan berat badan minimal, biasanya kurang dari 1 kg.\n"
                "• Asupan makanan cukup, namun kurang bervariasi (makan dua atau tiga kali sehari tetapi variasi makanan terbatas).\n"
                "• Masih bisa bergerak dengan bebas, tetapi mungkin mengalami sedikit keterbatasan dalam beberapa aktivitas fisik.\n"
                "• Masalah kesehatan mulut ringan, seperti sedikit kesulitan mengunyah.\n"
                "• Mengalami stres ringan tetapi tanpa dampak besar terhadap status kesehatan.\n"
                "Intervensi:\n"
                "• Pengaturan pola makan yang lebih seimbang dan bervariasi untuk mencegah malnutrisi lebih lanjut.\n"
                "• Kegiatan fisik ringan yang teratur untuk menjaga kesehatan fisik dan mobilitas.\n"
                "• Konseling psikologis ringan, jika diperlukan, untuk membantu manajemen stres.\n"
                "• Pengawasan berkala terhadap status gizi untuk memastikan stabilitas kondisi.\n")
    elif cluster == 1:
        return ("Klaster 4 - Cukup Gizi:\n"
                "Ciri-ciri:\n"
                "• Tidak ada penurunan berat badan atau stabil selama beberapa waktu.\n"
                "• Asupan makanan mencukupi dan bervariasi, makan tiga kali sehari dengan makanan kaya nutrisi.\n"
                "• Mobilitas penuh tanpa bantuan atau keterbatasan yang signifikan.\n"
                "• Tidak ada masalah kesehatan mulut yang menghambat asupan makanan.\n"
                "• Tidak ada masalah kesehatan kronis yang signifikan atau masalah kognitif berat.\n"
                "Intervensi:\n"
                "• Pemeliharaan gizi dengan pola makan yang seimbang dan aktivitas fisik teratur.\n"
                "• Konsultasi berkala dengan ahli gizi untuk memastikan asupan nutrisi tetap optimal.\n"
                "• Pemantauan kondisi kesehatan secara teratur untuk mendeteksi perubahan status gizi atau kondisi fisik.\n")
    else:
        return "Klaster tidak diketahui."

# Tampilkan intervensi
print(intervensi(label_baru))
# Out:
# Klaster 3 - Malnutrisi Ringan:
# Ciri-ciri:
# • Penurunan berat badan minimal, biasanya kurang dari 1 kg.
# • Asupan makanan cukup, namun kurang bervariasi (makan dua atau tiga kali sehari tetapi variasi makanan terbatas).
# • Masih bisa bergerak dengan bebas, tetapi mungkin mengalami sedikit keterbatasan dalam beberapa aktivitas fisik.
# • Masalah kesehatan mulut ringan, seperti sedikit kesulitan mengunyah.
# • Mengalami stres ringan tetapi tanpa dampak besar terhadap status kesehatan.
# Intervensi:
# • Pengaturan pola makan yang lebih seimbang dan bervariasi untuk mencegah malnutrisi lebih lanjut.
# • Kegiatan fisik ringan yang teratur untuk menjaga kesehatan fisik dan mobilitas.
# • Konseling psikologis ringan, jika diperlukan, untuk membantu manajemen stres.
# • Pengawasan berkala terhadap status gizi untuk memastikan stabilitas kondisi.

# %%
# Visualisasi dengan PCA
data_np = data_scaled.values
pca = PCA(n_components=2)
data_pca = pca.fit_transform(data_np)

# Transformasi data baru untuk PCA
data_baru_pca = pca.transform(data_baru_scaled)

# Visualisasi
plt.figure(figsize=(10, 6))

# Data lama
plt.scatter(data_pca[:, 0], data_pca[:, 1], c=labels, cmap='viridis', label='Data Lama', alpha=0.6)

# Data baru
plt.scatter(data_baru_pca[:, 0], data_baru_pca[:, 1], c=label_baru, cmap='plasma', label='Data Baru', marker='x', s=100)

plt.title('PCA of Clusters')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.colorbar(label='Cluster Label')
plt.legend()
plt.show()

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

# Hitung metrik evaluasi
silhouette_avg = silhouette_score(data_np, labels)
db_index = davies_bouldin_score(data_np, labels)
ch_index = calinski_harabasz_score(data_np, labels)

print(f'Silhouette Score: {silhouette_avg:.2f}')
print(f'Davies-Bouldin Index: {db_index:.2f}')
print(f'Calinski-Harabasz Index: {ch_index:.2f}')
# Out:
# Silhouette Score: 0.25
# Davies-Bouldin Index: 1.14
# Calinski-Harabasz Index: 83.27
